# %% [markdown]
# ## Image3Pipeline   (MIRI CALIMAGE3)
#
# `Image3Pipeline` combines the calibrated data from multiple exposures (e.g. a dither or mosaic pattern) into a single rectified (distortion corrected) product. Before being combined, the exposures receive additional corrections for the purpose of astrometric alignment, background matching, and outlier rejection.
#
# Official documentation for `Image3Pipeline` can be found here:
#
# <https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_image3.html>
#
# The `Image3Pipeline` comprises a linear series of steps. The steps applied to MIRI data in order are:
#
# |Step|Description|
# |:---|:---|
# |`tweakreg`|refine the WCS solution by comparing source catalogues from input images|
# |`skymatch`|compute sky values in a collection of input images that contain both sky and source signal|
# |`outlier_detection`|identification of bad pixels or cosmic-rays that remain in each of the input images|
# |`resample`|resample using WCS and distortion information into an undistorted product|
# |`source_catalog`|resample using WCS and distortion information into an undistorted product|
#
#
# For more information and examples of each of the steps click on the links in the side bar.

# %% [markdown]
# ### Input data
#
# An example of running the file through the `Image3Pipeline` is now shown using a simple simulated 4-point dither observation of a galaxy with the MIRI Imager (F1130W filter) produced with [MIRISim v2.1](http://miri.ster.kuleuven.be/bin/view/Public/MIRISimPublicRelease2dot1) and brought to level 2B using the `Detector1Pipeline` and `Image2Pipeline` modules.

# %% [markdown]
# ### Python
#
# Start by importing what will be used and set the `CRDS_CONTEXT`

# %%
# imports
import os, glob, shutil
import numpy as np
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
from subprocess import call
from jwst import datamodels
from jwst.associations.lib.member import Member
from jwst.associations.asn_from_list import asn_from_list
from astropy.table import Table
from photutils import CircularAperture

# set the CRDS_CONTEXT
os.environ["CRDS_CONTEXT"] = "jwst_0535.pmap"

# %% [markdown]
# `Image2Pipeline` can be run by passing indivual exposures or datamodels but in this sample case we produce an association file that links the background exposures to the science exposures so it can be subtracted. It is assumed that the science files are in 'IMA_science' and the background file is in 'IMA_background'. The content of the association file is printed for inspection.

# %%
# load the science and background files to lists
my_science_files = glob.glob('IMA_science/*cal.fits')
my_science_files = sorted(my_science_files)

# set the association name
asn_name = 'my_galaxy'

# setup an empty level 2 association structure
asn = asn_from_list(my_science_files, product_name=asn_name)

# set some metadata
asn['asn_pool'] = asn_name + '_pool'
asn['asn_type'] = 'image3'
        
# print the association and save to file
name, ser = asn.dump()
print(ser)

asn_file = asn_name + '_lvl3_asn.json'
with open(asn_file, 'w') as f:
    f.write(ser)
# Out:
# {
#     "asn_type": "image3",
#     "asn_rule": "DMS_Level3_Base",
#     "version_id": null,
#     "code_version": "0.13.7",
#     "degraded_status": "No known degraded exposures in association.",
#     "program": "noprogram",
#     "constraints": "No constraints",
#     "asn_id": "a3001",
#     "target": "none",
#     "asn_pool": "my_galaxy_pool",
#     "products": [
#         {
#             "name": "my_galaxy",
#             "members": [
#                 {
#                     "expname": "IMA_science/my_galaxy_dither1_cal.fits",
#                     "exptype": "science"
#                 },
#                 {
#                     "expname": "IMA_science/my_galaxy_dither2_cal.fits",
#                     "exptype": "science"
#                 },
#                 {
#                     "expname": "IMA_science/my_galaxy_dither3_cal.fits",
#                     "exptype": "science"
#                 },
#                 {
#                     "expname": "IMA_science/my_galaxy_dither4_cal.fits",
#                     "exptype": "science"
#                 }
#             ]
#         }
#     ]
# }

# %% [markdown]
# Import Image2Pipeline and print the docstring to show some information

# %%
from jwst.pipeline import Image3Pipeline
print(Image3Pipeline.__doc__)
# Out:
#     Image3Pipeline: Applies level 3 processing to imaging-mode data from
#                     any JWST instrument.
#
#     Included steps are:
#         tweakreg
#         skymatch
#         outlier_detection
#         resample
#         source_catalog

# %% [markdown]
# The association file is passed as input. The output level 2B files will be saved in `my_output_dir` as `_cal.fits`.
#
# *Parameters used:*
#
# `save_results`: boolean, optional, default=False
# &nbsp;&nbsp;&nbsp;&nbsp; save the results to file
#
# `output_dir` : boolean, optional, default is the working directory
# &nbsp;&nbsp;&nbsp;&nbsp; the location to save the output
#
# There are still some issues with the tweakreg step so this is skipped for now. We also set the source detection parameters and explicitly save the output from the `source_catalog` step.

# %%
# user specified
my_output_dir = 'demo_output'

# the output directory should be created if it doesn't exist
if not os.path.exists(my_output_dir): 
    os.mkdir(my_output_dir)

# run the pipeline
Image3Pipeline.call(asn_file, save_results=True, output_dir=my_output_dir,
                    steps={'tweakreg':{'skip':True},
                           'source_catalog':{'save_results':True, 'kernel_fwhm': 3.0, 'snr_threshold': 5.}})
# Out:
# 2019-07-22 15:50:56,217 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2019-07-22 15:50:56,220 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2019-07-22 15:50:56,222 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2019-07-22 15:50:56,225 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2019-07-22 15:50:56,227 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2019-07-22 15:50:56,229 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2019-07-22 15:50:56,315 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline running with args ('my_galaxy_lvl3_asn.json',).
# 2019-07-22 15:50:57,434 - stpipe.Image3Pipeline - INFO - Prefetching reference files for dataset: 'my_galaxy_dither1_cal.fits' reftypes = ['drizpars']
# 2019-07-22 15:50:57,438 - stpipe.Image3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2019-07-22 15:50:57,439 - stpipe.Image3Pipeline - INFO - Prefetching reference files for dataset: 'my_galaxy_dither2_cal.fits' reftypes = ['drizpars']
# 2019-07-22 15:50:57,443 - stpipe.Image3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2019-07-22 15:50:57,444 - stpipe.Image3Pipeline - INFO - Prefetching reference files for dataset: 'my_galaxy_dither3_cal.fits' reftypes = ['drizpars']
# 2019-07-22 15:50:57,449 - stpipe.Image3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2019-07-22 15:50:57,450 - stpipe.Image3Pipeline - INFO - Prefetching reference files for dataset: 'my_galaxy_dither4_cal.fits' reftypes = ['drizpars']
# 2019-07-22 15:50:57,454 - stpipe.Image3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2019-07-22 15:50:57,455 - stpipe.Image3Pipeline - INFO - Starting calwebb_image3 ...
# 2019-07-22 15:50:58,681 - stpipe.Image3Pipeline - INFO - Aligning input images...
# 2019-07-22 15:50:58,739 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg running with args (<ModelContainer>,).
# 2019-07-22 15:50:58,739 - stpipe.Image3Pipeline.tweakreg - INFO - Step skipped.
# 2019-07-22 15:50:58,743 - stpipe.Image3Pipeline.tweakreg - INFO - Step tweakreg done
# 2019-07-22 15:50:58,743 - stpipe.Image3Pipeline - INFO - Matching sky values across all input images...
# 2019-07-22 15:50:58,795 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch running with args (<ModelContainer>,).
# 2019-07-22 15:50:58,940 - stpipe.Image3Pipeline.skymatch - INFO -
# 2019-07-22 15:50:58,941 - stpipe.Image3Pipeline.skymatch - INFO - ***** jwst.skymatch.skymatch.match() started on 2019-07-22 15:50:58.940642
# 2019-07-22 15:50:58,942 - stpipe.Image3Pipeline.skymatch - INFO -
# 2019-07-22 15:50:58,942 - stpipe.Image3Pipeline.skymatch - INFO - Sky computation method: 'global+match'
# 2019-07-22 15:50:58,943 - stpipe.Image3Pipeline.skymatch - INFO - Sky matching direction: DOWN
# 2019-07-22 15:50:58,943 - stpipe.Image3Pipeline.skymatch - INFO - Sky subtraction from image data: OFF
# 2019-07-22 15:50:58,944 - stpipe.Image3Pipeline.skymatch - INFO -
# 2019-07-22 15:50:58,945 - stpipe.Image3Pipeline.skymatch - INFO - ----  Computing differences in sky values in overlapping regions.
# 2019-07-22 15:51:01,138 - stpipe.Image3Pipeline.skymatch - INFO -    *  Image ID=my_galaxy_dither1_cal.fits. Sky background: 0
# 2019-07-22 15:51:01,139 - stpipe.Image3Pipeline.skymatch - INFO -    *  Image ID=my_galaxy_dither2_cal.fits. Sky background: 0.415459
# 2019-07-22 15:51:01,140 - stpipe.Image3Pipeline.skymatch - INFO -    *  Image ID=my_galaxy_dither3_cal.fits. Sky background: 0.525784
# 2019-07-22 15:51:01,141 - stpipe.Image3Pipeline.skymatch - INFO -    *  Image ID=my_galaxy_dither4_cal.fits. Sky background: 0.322074
# 2019-07-22 15:51:01,141 - stpipe.Image3Pipeline.skymatch - INFO -
# 2019-07-22 15:51:01,142 - stpipe.Image3Pipeline.skymatch - INFO - ----  Computing "global" sky - smallest sky value across *all* input images.
# 2019-07-22 15:51:01,213 - stpipe.Image3Pipeline.skymatch - INFO -
# 2019-07-22 15:51:01,214 - stpipe.Image3Pipeline.skymatch - INFO -    "Global" sky value correction: 0.168472738813627 [not converted]
# 2019-07-22 15:51:01,214 - stpipe.Image3Pipeline.skymatch - INFO -
# 2019-07-22 15:51:01,215 - stpipe.Image3Pipeline.skymatch - INFO - ----  Final (match+global) sky for:
# 2019-07-22 15:51:01,215 - stpipe.Image3Pipeline.skymatch - INFO -    *  Image ID=my_galaxy_dither1_cal.fits. Sky background: 0.168473 (old=0, delta=0.168473)
# 2019-07-22 15:51:01,216 - stpipe.Image3Pipeline.skymatch - INFO -    *  Image ID=my_galaxy_dither2_cal.fits. Sky background: 0.583931 (old=0.415459, delta=0.168473)
# 2019-07-22 15:51:01,216 - stpipe.Image3Pipeline.skymatch - INFO -    *  Image ID=my_galaxy_dither3_cal.fits. Sky background: 0.694257 (old=0.525784, delta=0.168473)
# 2019-07-22 15:51:01,217 - stpipe.Image3Pipeline.skymatch - INFO -    *  Image ID=my_galaxy_dither4_cal.fits. Sky background: 0.490547 (old=0.322074, delta=0.168473)
# 2019-07-22 15:51:01,218 - stpipe.Image3Pipeline.skymatch - INFO -
# 2019-07-22 15:51:01,219 - stpipe.Image3Pipeline.skymatch - INFO - ***** jwst.skymatch.skymatch.match() ended on 2019-07-22 15:51:01.218370
# 2019-07-22 15:51:01,220 - stpipe.Image3Pipeline.skymatch - INFO - ***** jwst.skymatch.skymatch.match() TOTAL RUN TIME: 0:00:02.277728
# 2019-07-22 15:51:01,220 - stpipe.Image3Pipeline.skymatch - INFO -
# 2019-07-22 15:51:01,230 - stpipe.Image3Pipeline.skymatch - INFO - Step skymatch done
# 2019-07-22 15:51:01,231 - stpipe.Image3Pipeline - INFO - Performing outlier detection on input images...
# 2019-07-22 15:51:01,302 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2019-07-22 15:51:01,306 - stpipe.Image3Pipeline.outlier_detection - INFO - Performing outlier detection on 4 inputs
# 2019-07-22 15:51:02,184 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1218, 1177)
# 2019-07-22 15:51:03,059 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1218, 1177)
# 2019-07-22 15:51:03,943 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1218, 1177)
# 2019-07-22 15:51:04,826 - stpipe.Image3Pipeline.outlier_detection - INFO - Drizzling (1024, 1032) --> (1218, 1177)
# 2019-07-22 15:51:05,698 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting median...
# 2019-07-22 15:51:06,156 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1218, 1177)
# 2019-07-22 15:51:06,705 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1218, 1177)
# 2019-07-22 15:51:07,338 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1218, 1177)
# 2019-07-22 15:51:08,074 - stpipe.Image3Pipeline.outlier_detection - INFO - Blotting (1024, 1032) <-- (1218, 1177)
# 2019-07-22 15:51:08,419 - stpipe.Image3Pipeline.outlier_detection - WARNING - /anaconda3/envs/jwst7.3/lib/python3.6/site-packages/jwst-0.13.7-py3.6.egg/jwst/outlier_detection/outlier_detection.py:415: RuntimeWarning: overflow encountered in square
#   ta = np.sqrt(np.abs(blot_data + subtracted_background) + err_data ** 2)
#
# 2019-07-22 15:51:08,910 - stpipe.Image3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2019-07-22 15:51:08,911 - stpipe.Image3Pipeline - INFO - Writing Level 2c images with updated DQ arrays...
# 2019-07-22 15:51:09,317 - stpipe.Image3Pipeline - INFO - Saved model in demo_output/my_galaxy_dither1_a3001_crf.fits
# 2019-07-22 15:51:09,606 - stpipe.Image3Pipeline - INFO - Saved model in demo_output/my_galaxy_dither2_a3001_crf.fits
# 2019-07-22 15:51:09,863 - stpipe.Image3Pipeline - INFO - Saved model in demo_output/my_galaxy_dither3_a3001_crf.fits
# 2019-07-22 15:51:10,141 - stpipe.Image3Pipeline - INFO - Saved model in demo_output/my_galaxy_dither4_a3001_crf.fits
# 2019-07-22 15:51:10,142 - stpipe.Image3Pipeline - INFO - Resampling images to final result...
# 2019-07-22 15:51:10,260 - stpipe.Image3Pipeline.resample - INFO - Step resample running with args (<ModelContainer>,).
# 2019-07-22 15:51:10,267 - stpipe.Image3Pipeline.resample - INFO - Drizpars reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2019-07-22 15:51:10,807 - stpipe.Image3Pipeline.resample - INFO - Blending metadata for my_galaxy
# 2019-07-22 15:51:11,948 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1218, 1177)
# 2019-07-22 15:51:12,935 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1218, 1177)
# 2019-07-22 15:51:14,020 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1218, 1177)
# 2019-07-22 15:51:15,049 - stpipe.Image3Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1218, 1177)
# 2019-07-22 15:51:15,657 - stpipe.Image3Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  0.022925405 -0.018241897 0.022925405 0.019302552 359.986644766 0.019302552 359.986644766 -0.018241897
# 2019-07-22 15:51:15,661 - stpipe.Image3Pipeline.resample - INFO - Step resample done
# 2019-07-22 15:51:16,307 - stpipe.Image3Pipeline - INFO - Saved model in demo_output/my_galaxy_i2d.fits
# 2019-07-22 15:51:16,308 - stpipe.Image3Pipeline - INFO - Creating source catalog...
# 2019-07-22 15:51:16,388 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog running with args (<DrizProductModel(1218, 1177) from my_galaxy_i2d.fits>,).
# 2019-07-22 15:51:16,773 - stpipe.Image3Pipeline.source_catalog - WARNING - /anaconda3/envs/jwst7.3/lib/python3.6/site-packages/astropy/io/fits/card.py:1003: VerifyWarning: Card is too long, comment will be truncated.
#   VerifyWarning)
#
# 2019-07-22 15:51:16,947 - stpipe.Image3Pipeline.source_catalog - INFO - Detected 58 sources
# 2019-07-22 15:51:16,997 - stpipe.Image3Pipeline.source_catalog - INFO - Wrote source catalog: demo_output/my_galaxy_cat.ecsv
# 2019-07-22 15:51:16,999 - stpipe.Image3Pipeline.source_catalog - INFO - Step source_catalog done
# 2019-07-22 15:51:17,000 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline done

# %% [markdown]
# We can plot the before (rate) and after (cal) images for the first dither position

# %%
driz_dm = datamodels.open(os.path.join(my_output_dir,'my_galaxy_i2d.fits'))

# plot--------------------------------------
fig, axs = plt.subplots(1, 1, figsize=(8, 8))

# show last frame of first integration
axs.imshow(driz_dm.data, cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1,vmax=1000))
axs.annotate('Drizzled image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs.set_facecolor('black')

plt.tight_layout()
plt.show()

# %%
my_catalog = os.path.join(my_output_dir,'my_galaxy_cat.ecsv')
sources = Table.read(my_catalog, format='ascii.ecsv')

print(sources.columns)    # print all available column names
print()
sources['id', 'xcentroid', 'ycentroid', 'sky_centroid', 'abmag'].pprint(max_width=200)
# Out:
# <TableColumns names=('id','xcentroid','ycentroid','sky_centroid','area','source_sum','source_sum_err','semimajor_axis_sigma','semiminor_axis_sigma','orientation','sky_bbox_ll','sky_bbox_ul','sky_bbox_lr','sky_bbox_ur','orientation_sky','abmag','abmag_error')>
#
#  id     xcentroid          ycentroid                      sky_centroid                      abmag
#            pix                pix                           deg,deg
# --- ------------------ ------------------ ------------------------------------------- ------------------
#   1 465.25939576993323 40.767598552958766   0.008583937012964917,-0.01698524998560875 16.152284622192383
#   2  568.3622180032717 57.913999162100005  0.005405826227808111,-0.016456717874755146 16.889514923095703
#   3  164.7563000787361  70.21371069518692   0.017846846483682587,-0.01607758290250832 14.602665901184082
#   4  513.9016936083741  72.68328007704133  0.0070845540880800344,-0.01600145964444632 14.742581367492676
#   5 1085.5568581220841  82.54704966531347    359.98946347088093,-0.015697411646657236 15.485074996948242
#   6 171.49268328319963 107.75784694669974   0.01763919968649991,-0.014920297305474079 16.601314544677734
#   7 209.86581762346358 110.15638595172739  0.016456360418694485,-0.014846363197321787 15.497069358825684
#   8  598.7245119238983 148.58260588062467 0.0044699184430326356,-0.013661887912825368 15.577756881713867
#   9 1072.5671122650558  175.8522064633634     359.9898638755159,-0.012821311000786461  14.98459529876709
#  10  505.9080229428561 194.07867788175543   0.007330956374308184,-0.01225948642822593 16.684192657470703
# ...                ...                ...                                         ...                ...
#  49  621.9515457691189 1004.4686993185794   0.0037539527131079282,0.01272052072199663 14.990389823913574
#  50 183.52263612191038 1011.5359185546032   0.017268380396379193,0.012938365130401015 15.441108703613281
#  51  633.4047193897529 1033.7949339006002  0.0034009123786112516,0.013624492272658374 15.245550155639648
#  52  877.8609209468212 1058.1090481333663     359.99586562991306,0.014373966685780889  15.34005355834961
#  53  709.4948981143779 1069.5300510938273  0.0010554574864205767,0.014726015491426105 15.051849365234375
#  54  300.9372354468744  1090.932853650329   0.013649113868248054,0.015385749690284722 15.815946578979492
#  55  702.4257080437891 1117.5600330907555  0.0012733629588097557,0.016206523889388647 15.345070838928223
#  56 1047.4781157891077 1123.1867291021015      359.99063723551535,0.01637996447276041  15.25639533996582
#  57  651.8286691763414 1136.1013978650353   0.0028330001460103544,0.01677805537525324 14.973989486694336
#  58  1048.027816029701 1152.0138988019369      359.99062029118403,0.01726855245720346 15.692749977111816
# Length = 58 rows

# %%
# read source X,Y positions from the table, show with circles of radius 10pix
positions = (sources['xcentroid'], sources['ycentroid'])
apertures = CircularAperture(positions, r=15.)

# plot--------------------------------------
fig, axs = plt.subplots(1, 1, figsize=(8, 8))

# show last frame of first integration
axs.imshow(driz_dm.data, cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1,vmax=1000))
apertures.plot(color='yellow', lw=2.0, alpha=0.8)
axs.annotate('Drizzled image with detected sources', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs.set_facecolor('black')

plt.tight_layout()
plt.show()
# Out:
# 2019-07-22 15:51:18,058 - stpipe - WARNING - /anaconda3/envs/jwst7.3/lib/python3.6/site-packages/photutils/aperture/attributes.py:75: AstropyDeprecationWarning: Inputing positions shaped as 2xN is deprecated and will be removed in v0.8.  Positions should be a (x, y) pixel position or a list or array of (x, y) pixel positions, e.g. [(x1, y1), (x2, y2), (x3, y3)].
#   '(x2, y2), (x3, y3)].', AstropyDeprecationWarning)

# %% [markdown]
# ### Command line
#
# To achieve the same result from the command line there are a couple of options. However, one must still generate the association file. In this case, it is best to copy the template above into a text file and save it to `my_galaxy_lvl3_asn.json`. The content is printed here for convenience.

# %% [markdown]
# ```python
# {
#     "asn_type": "image3",
#     "asn_rule": "DMS_Level3_Base",
#     "version_id": null,
#     "code_version": "0.13.7",
#     "degraded_status": "No known degraded exposures in association.",
#     "program": "noprogram",
#     "constraints": "No constraints",
#     "asn_id": "a3001",
#     "target": "none",
#     "asn_pool": "my_galaxy_pool",
#     "products": [
#         {
#             "name": "my_galaxy",
#             "members": [
#                 {
#                     "expname": "IMA_science/my_galaxy_dither1_cal.fits",
#                     "exptype": "science"
#                 },
#                 {
#                     "expname": "IMA_science/my_galaxy_dither2_cal.fits",
#                     "exptype": "science"
#                 },
#                 {
#                     "expname": "IMA_science/my_galaxy_dither3_cal.fits",
#                     "exptype": "science"
#                 },
#                 {
#                     "expname": "IMA_science/my_galaxy_dither4_cal.fits",
#                     "exptype": "science"
#                 }
#             ]
#         }
#     ]
# }
# ```

# %% [markdown]
# **Option 1:**
# Run the `Image3Pipeline` class using the `strun` command:
#
# ```bash
# mkdir demo_output
#
# strun jwst.pipeline.Image3Pipeline my_galaxy_lvl3_asn.json --output_dir demo_output
# ```
#
# This will produce the same output file in the user-defined `--output_dir`
#
#
# **Option 2:**
# Collect the pipeline configuration files in your working directory (if they are not already there) using `collect_pipeline_configs` and then run the `Image3Pipeline` using the `strun` command with the associated `calwebb_image3.cfg` file. This option is a little more flexible as one can create edit the cfg files, use them again, etc.
#
# ```bash
# mkdir demo_output
#
# collect_pipeline_cfgs cfgs/
#
# strun cfgs/calwebb_image3.cfg my_galaxy_lvl3_asn.json --output_dir demo_output
# ```
#
# This will produce the same output file in the user-defined `--output_dir`

# %% [markdown]
# ## Further examples
#
# Other notebooks with more complex examples can be found here:
#
# *To be added*
