# %% [markdown]
# ## Image2Pipeline   (MIRI CALIMAGE2)
#
# `Image2Pipeline` applies instrumental corrections and calibrations, in addition to the subtraction of dedicated background exposures, that result in a fully calibrated, background subtracted individual exposures.
#
# Official documentation for `Image2Pipeline` can be found here:
#
# <https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_image2.html>
#
# The `Image2Pipeline` comprises a linear series of steps. The steps applied to MIRI data in order are:
#
# |Step|Description|
# |:---|:---|
# |`background`|subtract dedicated background exposures|
# |`assign_wcs`|attach WCS object to each science exposure|
# |`flat_field`|correct the exposure using the flat-field reference file|
# |`photom`|apply flux (photometric) calibration|
# |`resample`|resample using WCS and distortion information into an undistorted product|
#
#
# For more information and examples of each of the steps click on the links in the side bar.

# %% [markdown]
# ### Input data
#
# An example of running the file through the `Image2Pipeline` is now shown using a simple simulated 4-point dither observation of a galaxy with the MIRI Imager (F1130W filter) produced with [MIRISim v2.1](http://miri.ster.kuleuven.be/bin/view/Public/MIRISimPublicRelease2dot1) and brought to level 2A using the `Detector1Pipeline`. A background observation is also associated to the science exposures for subtraction.

# %% [markdown]
# ### Python
#
# Start by importing what will be used and set the `CRDS_CONTEXT`

# %%
# imports
import os, glob, shutil
import numpy as np
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
from subprocess import call
from jwst import datamodels
from jwst.associations.lib.member import Member
from jwst.associations.asn_from_list import asn_from_list
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase

# set the CRDS_CONTEXT
os.environ["CRDS_CONTEXT"] = "jwst_0535.pmap"

# %% [markdown]
# `Image2Pipeline` can be run by passing indivual exposures or datamodels but in this sample case we produce an association file that links the background exposures to the science exposures so it can be subtracted. It is assumed that the science files are in 'IMA_science' and the background file is in 'IMA_background'. The content of the association file is printed for inspection.

# %%
# load the science and background files to lists
my_science_files = glob.glob('IMA_science/*rate.fits')
my_background_files = glob.glob('IMA_background/*rate.fits')
my_science_files = sorted(my_science_files)

# setup an empty level 2 association structure
asn = asn_from_list(my_science_files, rule=DMSLevel2bBase)
asn.data['products'] = None

# set the association name
asn_name = 'my_galaxy'

# set some metadata
asn['asn_pool'] = asn_name + '_pool'
asn['asn_type'] = 'image2'

for n, sci in enumerate(my_science_files):
    asn.new_product('{}_dither{}'.format(asn_name, str(n+1)))
    sci_member = Member({'expname': sci, 'exptype': 'science'})    
    new_members = asn.current_product['members']
    new_members.append(sci_member)
    
    for bkg in my_background_files:
        bkg_member = Member({'expname': bkg, 'exptype': 'background'})
        new_members.append(bkg_member)
        
# print the association and save to file
name, ser = asn.dump()
print(ser)

asn_file = asn_name + '_lvl2_asn.json'
with open(asn_file, 'w') as f:
    f.write(ser)
# Out:
# {
#     "asn_type": "image2",
#     "asn_rule": "DMSLevel2bBase",
#     "version_id": null,
#     "code_version": "0.13.7",
#     "degraded_status": "No known degraded exposures in association.",
#     "program": "noprogram",
#     "products": [
#         {
#             "name": "my_galaxy_dither1",
#             "members": [
#                 {
#                     "expname": "IMA_science/det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits",
#                     "exptype": "science"
#                 },
#                 {
#                     "expname": "IMA_background/det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits",
#                     "exptype": "background"
#                 }
#             ]
#         },
#         {
#             "name": "my_galaxy_dither2",
#             "members": [
#                 {
#                     "expname": "IMA_science/det_image_seq2_MIRIMAGE_F1130Wexp1_rate.fits",
#                     "exptype": "science"
#                 },
#                 {
#                     "expname": "IMA_background/det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits",
#                     "exptype": "background"
#                 }
#             ]
#         },
#         {
#             "name": "my_galaxy_dither3",
#             "members": [
#                 {
#                     "expname": "IMA_science/det_image_seq3_MIRIMAGE_F1130Wexp1_rate.fits",
#                     "exptype": "science"
#                 },
#                 {
#                     "expname": "IMA_background/det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits",
#                     "exptype": "background"
#                 }
#             ]
#         },
#         {
#             "name": "my_galaxy_dither4",
#             "members": [
#                 {
#                     "expname": "IMA_science/det_image_seq4_MIRIMAGE_F1130Wexp1_rate.fits",
#                     "exptype": "science"
#                 },
#                 {
#                     "expname": "IMA_background/det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits",
#                     "exptype": "background"
#                 }
#             ]
#         }
#     ],
#     "asn_pool": "my_galaxy_pool"
# }

# %% [markdown]
# Import Image2Pipeline and print the docstring to show some information

# %%
from jwst.pipeline import Image2Pipeline
print(Image2Pipeline.__doc__)
# Out:
#     Image2Pipeline: Processes JWST imaging-mode slope data from Level-2a to
#     Level-2b.
#
#     Included steps are:
#     background_subtraction, assign_wcs, flat_field, photom and resample.

# %% [markdown]
# The association file is passed as input. The output level 2B files will be saved in `my_output_dir` as `_cal.fits`.
#
# *Parameters used:*
#
# `save_results`: boolean, optional, default=False
# &nbsp;&nbsp;&nbsp;&nbsp; save the results to file
#
# `output_dir` : boolean, optional, default is the working directory
# &nbsp;&nbsp;&nbsp;&nbsp; the location to save the output
#
# Note that the `Image2Pipeline` will return the level 2B datamodel for each exposure as a list of datamodels so we set these to `dm_cont`. The output filenames will be determined by the `asn_name` in the association file which was set in the cell above.

# %%
# user specified
my_output_dir = 'demo_output'

# the output directory should be created if it doesn't exist
if not os.path.exists(my_output_dir): 
    os.mkdir(my_output_dir)

# run the pipeline
dm_cont = Image2Pipeline.call(asn_file, save_results=True, output_dir=my_output_dir)
# Out:
# 2019-07-19 14:26:50,735 - stpipe.Image2Pipeline - INFO - Image2Pipeline instance created.
# 2019-07-19 14:26:50,737 - stpipe.Image2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2019-07-19 14:26:50,739 - stpipe.Image2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2019-07-19 14:26:50,740 - stpipe.Image2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2019-07-19 14:26:50,742 - stpipe.Image2Pipeline.photom - INFO - PhotomStep instance created.
# 2019-07-19 14:26:50,744 - stpipe.Image2Pipeline.resample - INFO - ResampleStep instance created.
# 2019-07-19 14:26:50,792 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline running with args ('my_galaxy_lvl2_asn.json',).
# 2019-07-19 14:26:51,255 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2019-07-19 14:26:52,576 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_area_0004.fits'.
# 2019-07-19 14:26:52,577 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2019-07-19 14:26:52,578 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2019-07-19 14:26:52,578 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2019-07-19 14:26:52,579 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2019-07-19 14:26:52,580 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0028.asdf'.
# 2019-07-19 14:26:52,581 - stpipe.Image2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2019-07-19 14:26:52,581 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2019-07-19 14:26:52,582 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_filteroffset_0004.asdf'.
# 2019-07-19 14:26:52,583 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_flat_0422.fits'.
# 2019-07-19 14:26:52,583 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2019-07-19 14:26:52,584 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2019-07-19 14:26:52,585 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2019-07-19 14:26:52,585 - stpipe.Image2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2019-07-19 14:26:52,586 - stpipe.Image2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2019-07-19 14:26:52,587 - stpipe.Image2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2019-07-19 14:26:52,587 - stpipe.Image2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2019-07-19 14:26:52,588 - stpipe.Image2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0042.fits'.
# 2019-07-19 14:26:52,589 - stpipe.Image2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2019-07-19 14:26:52,590 - stpipe.Image2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2019-07-19 14:26:52,591 - stpipe.Image2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2019-07-19 14:26:52,592 - stpipe.Image2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2019-07-19 14:26:52,593 - stpipe.Image2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2019-07-19 14:26:52,595 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2019-07-19 14:26:52,602 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_area_0004.fits'.
# 2019-07-19 14:26:52,603 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2019-07-19 14:26:52,603 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2019-07-19 14:26:52,604 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2019-07-19 14:26:52,604 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2019-07-19 14:26:52,606 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0028.asdf'.
# 2019-07-19 14:26:52,607 - stpipe.Image2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2019-07-19 14:26:52,609 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2019-07-19 14:26:52,610 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_filteroffset_0004.asdf'.
# 2019-07-19 14:26:52,611 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_flat_0422.fits'.
# 2019-07-19 14:26:52,612 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2019-07-19 14:26:52,613 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2019-07-19 14:26:52,614 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2019-07-19 14:26:52,614 - stpipe.Image2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2019-07-19 14:26:52,615 - stpipe.Image2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2019-07-19 14:26:52,616 - stpipe.Image2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2019-07-19 14:26:52,616 - stpipe.Image2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2019-07-19 14:26:52,617 - stpipe.Image2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0042.fits'.
# 2019-07-19 14:26:52,618 - stpipe.Image2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2019-07-19 14:26:52,619 - stpipe.Image2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2019-07-19 14:26:52,620 - stpipe.Image2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2019-07-19 14:26:52,620 - stpipe.Image2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2019-07-19 14:26:52,621 - stpipe.Image2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2019-07-19 14:26:52,622 - stpipe.Image2Pipeline - INFO - Starting calwebb_image2 ...
# 2019-07-19 14:26:52,636 - stpipe.Image2Pipeline - INFO - Processing product my_galaxy_dither1
# 2019-07-19 14:26:52,637 - stpipe.Image2Pipeline - INFO - Working on input IMA_science/det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits ...
# 2019-07-19 14:26:52,787 - stpipe.Image2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<ImageModel(1024, 1032) from det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits>, ['IMA_background/det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits']).
# 2019-07-19 14:26:53,187 - stpipe.Image2Pipeline.bkg_subtract - INFO - Step bkg_subtract done
# 2019-07-19 14:26:53,242 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<ImageModel(1024, 1032) from det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits>,).
# 2019-07-19 14:26:53,592 - stpipe.Image2Pipeline.assign_wcs - WARNING - /anaconda3/envs/jwst7.3/lib/python3.6/site-packages/asdf/asdf.py:202: UserWarning: File 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0028.asdf' was created with extension 'asdf.extension.BuiltinExtension' from package asdf-2.4.0.dev1705, but older version asdf-2.4.0.dev58+g96f5e34 is installed
#   warnings.warn(fmt_msg)
# 2019-07-19 14:26:53,605 - stpipe.Image2Pipeline.assign_wcs - WARNING - /anaconda3/envs/jwst7.3/lib/python3.6/site-packages/asdf/asdf.py:202: UserWarning: File 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_filteroffset_0004.asdf' was created with extension 'asdf.extension.BuiltinExtension' from package asdf-2.4.0.dev1705, but older version asdf-2.4.0.dev58+g96f5e34 is installed
#   warnings.warn(fmt_msg)
#
# 2019-07-19 14:26:53,628 - stpipe.Image2Pipeline.assign_wcs - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0028.asdf', 'filteroffset': '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_filteroffset_0004.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2019-07-19 14:26:53,704 - stpipe.Image2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  0.020134820 -0.018428143 0.022602426 0.012759026 359.991543317 0.015331680 359.988736249 -0.015869190
# 2019-07-19 14:26:53,705 - stpipe.Image2Pipeline.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  0.020134820 -0.018428143 0.022602426 0.012759026 359.991543317 0.015331680 359.988736249 -0.015869190
# 2019-07-19 14:26:53,706 - stpipe.Image2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2019-07-19 14:26:53,713 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2019-07-19 14:26:53,766 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field running with args (<ImageModel(1024, 1032) from det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits>,).
# 2019-07-19 14:26:53,913 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-07-19 14:26:53,914 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-07-19 14:26:53,915 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-07-19 14:26:53,923 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-07-19 14:26:54,050 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field done
# 2019-07-19 14:26:54,100 - stpipe.Image2Pipeline.photom - INFO - Step photom running with args (<ImageModel(1024, 1032) from det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits>,).
# 2019-07-19 14:26:54,117 - stpipe.Image2Pipeline.photom - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0042.fits
# 2019-07-19 14:26:54,121 - stpipe.Image2Pipeline.photom - INFO - Using area reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_area_0004.fits
# 2019-07-19 14:26:54,181 - stpipe.Image2Pipeline.photom - INFO - Using instrument: MIRI
# 2019-07-19 14:26:54,181 - stpipe.Image2Pipeline.photom - INFO -  detector: MIRIMAGE
# 2019-07-19 14:26:54,182 - stpipe.Image2Pipeline.photom - INFO -  exp_type: MIR_IMAGE
# 2019-07-19 14:26:54,182 - stpipe.Image2Pipeline.photom - INFO -  filter: F1130W
# 2019-07-19 14:26:54,213 - stpipe.Image2Pipeline.photom - INFO -  subarray: FULL
# 2019-07-19 14:26:54,215 - stpipe.Image2Pipeline.photom - INFO - PHOTMJSR value: 2.44947
# 2019-07-19 14:26:54,243 - stpipe.Image2Pipeline.photom - INFO - Pixel area map copied to output.
# 2019-07-19 14:26:54,248 - stpipe.Image2Pipeline.photom - INFO - Step photom done
# 2019-07-19 14:26:54,305 - stpipe.Image2Pipeline.resample - INFO - Step resample running with args (<ImageModel(1024, 1032) from det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits>,).
# 2019-07-19 14:26:54,324 - stpipe.Image2Pipeline.resample - INFO - Drizpars reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2019-07-19 14:26:54,956 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1095, 1099)
# 2019-07-19 14:26:55,463 - stpipe.Image2Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  0.022701222 -0.018447633 0.022701222 0.015305382 359.988824907 0.015305382 359.988824907 -0.018447633
# 2019-07-19 14:26:55,466 - stpipe.Image2Pipeline.resample - INFO - Step resample done
# 2019-07-19 14:26:55,467 - stpipe.Image2Pipeline - INFO - Finished processing product my_galaxy_dither1
# 2019-07-19 14:26:55,468 - stpipe.Image2Pipeline - INFO - Processing product my_galaxy_dither2
# 2019-07-19 14:26:55,469 - stpipe.Image2Pipeline - INFO - Working on input IMA_science/det_image_seq2_MIRIMAGE_F1130Wexp1_rate.fits ...
# 2019-07-19 14:26:55,647 - stpipe.Image2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<ImageModel(1024, 1032) from det_image_seq2_MIRIMAGE_F1130Wexp1_rate.fits>, ['IMA_background/det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits']).
# 2019-07-19 14:26:56,032 - stpipe.Image2Pipeline.bkg_subtract - INFO - Step bkg_subtract done
# 2019-07-19 14:26:56,085 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<ImageModel(1024, 1032) from det_image_seq2_MIRIMAGE_F1130Wexp1_rate.fits>,).
# 2019-07-19 14:26:56,360 - stpipe.Image2Pipeline.assign_wcs - WARNING - /anaconda3/envs/jwst7.3/lib/python3.6/site-packages/asdf/asdf.py:202: UserWarning: File 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0028.asdf' was created with extension 'asdf.extension.BuiltinExtension' from package asdf-2.4.0.dev1705, but older version asdf-2.4.0.dev58+g96f5e34 is installed
#   warnings.warn(fmt_msg)
#
# 2019-07-19 14:26:56,370 - stpipe.Image2Pipeline.assign_wcs - WARNING - /anaconda3/envs/jwst7.3/lib/python3.6/site-packages/asdf/asdf.py:202: UserWarning: File 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_filteroffset_0004.asdf' was created with extension 'asdf.extension.BuiltinExtension' from package asdf-2.4.0.dev1705, but older version asdf-2.4.0.dev58+g96f5e34 is installed
#   warnings.warn(fmt_msg)
#
# 2019-07-19 14:26:56,392 - stpipe.Image2Pipeline.assign_wcs - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0028.asdf', 'filteroffset': '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_filteroffset_0004.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2019-07-19 14:26:56,472 - stpipe.Image2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  0.019495671 -0.017106351 0.021963278 0.014080819 359.990904168 0.016653473 359.988097101 -0.014547397
# 2019-07-19 14:26:56,472 - stpipe.Image2Pipeline.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  0.019495671 -0.017106351 0.021963278 0.014080819 359.990904168 0.016653473 359.988097101 -0.014547397
# 2019-07-19 14:26:56,473 - stpipe.Image2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2019-07-19 14:26:56,481 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2019-07-19 14:26:56,535 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field running with args (<ImageModel(1024, 1032) from det_image_seq2_MIRIMAGE_F1130Wexp1_rate.fits>,).
# 2019-07-19 14:26:56,618 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-07-19 14:26:56,619 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-07-19 14:26:56,620 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-07-19 14:26:56,627 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-07-19 14:26:56,720 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field done
# 2019-07-19 14:26:56,766 - stpipe.Image2Pipeline.photom - INFO - Step photom running with args (<ImageModel(1024, 1032) from det_image_seq2_MIRIMAGE_F1130Wexp1_rate.fits>,).
# 2019-07-19 14:26:56,782 - stpipe.Image2Pipeline.photom - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0042.fits
# 2019-07-19 14:26:56,786 - stpipe.Image2Pipeline.photom - INFO - Using area reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_area_0004.fits
# 2019-07-19 14:26:56,857 - stpipe.Image2Pipeline.photom - INFO - Using instrument: MIRI
# 2019-07-19 14:26:56,858 - stpipe.Image2Pipeline.photom - INFO -  detector: MIRIMAGE
# 2019-07-19 14:26:56,858 - stpipe.Image2Pipeline.photom - INFO -  exp_type: MIR_IMAGE
# 2019-07-19 14:26:56,859 - stpipe.Image2Pipeline.photom - INFO -  filter: F1130W
# 2019-07-19 14:26:56,891 - stpipe.Image2Pipeline.photom - INFO -  subarray: FULL
# 2019-07-19 14:26:56,892 - stpipe.Image2Pipeline.photom - INFO - PHOTMJSR value: 2.44947
# 2019-07-19 14:26:56,923 - stpipe.Image2Pipeline.photom - INFO - Pixel area map copied to output.
# 2019-07-19 14:26:56,929 - stpipe.Image2Pipeline.photom - INFO - Step photom done
# 2019-07-19 14:26:56,984 - stpipe.Image2Pipeline.resample - INFO - Step resample running with args (<ImageModel(1024, 1032) from det_image_seq2_MIRIMAGE_F1130Wexp1_rate.fits>,).
# 2019-07-19 14:26:57,008 - stpipe.Image2Pipeline.resample - INFO - Drizpars reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2019-07-19 14:26:57,631 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1095, 1099)
# 2019-07-19 14:26:58,178 - stpipe.Image2Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  0.022062073 -0.017125840 0.022062073 0.016627174 359.988185759 0.016627174 359.988185759 -0.017125840
# 2019-07-19 14:26:58,181 - stpipe.Image2Pipeline.resample - INFO - Step resample done
# 2019-07-19 14:26:58,182 - stpipe.Image2Pipeline - INFO - Finished processing product my_galaxy_dither2
# 2019-07-19 14:26:58,183 - stpipe.Image2Pipeline - INFO - Processing product my_galaxy_dither3
# 2019-07-19 14:26:58,184 - stpipe.Image2Pipeline - INFO - Working on input IMA_science/det_image_seq3_MIRIMAGE_F1130Wexp1_rate.fits ...
# 2019-07-19 14:26:58,372 - stpipe.Image2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<ImageModel(1024, 1032) from det_image_seq3_MIRIMAGE_F1130Wexp1_rate.fits>, ['IMA_background/det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits']).
# 2019-07-19 14:26:58,747 - stpipe.Image2Pipeline.bkg_subtract - INFO - Step bkg_subtract done
# 2019-07-19 14:26:58,808 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<ImageModel(1024, 1032) from det_image_seq3_MIRIMAGE_F1130Wexp1_rate.fits>,).
# 2019-07-19 14:26:59,087 - stpipe.Image2Pipeline.assign_wcs - WARNING - /anaconda3/envs/jwst7.3/lib/python3.6/site-packages/asdf/asdf.py:202: UserWarning: File 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0028.asdf' was created with extension 'asdf.extension.BuiltinExtension' from package asdf-2.4.0.dev1705, but older version asdf-2.4.0.dev58+g96f5e34 is installed
#   warnings.warn(fmt_msg)
#
# 2019-07-19 14:26:59,098 - stpipe.Image2Pipeline.assign_wcs - WARNING - /anaconda3/envs/jwst7.3/lib/python3.6/site-packages/asdf/asdf.py:202: UserWarning: File 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_filteroffset_0004.asdf' was created with extension 'asdf.extension.BuiltinExtension' from package asdf-2.4.0.dev1705, but older version asdf-2.4.0.dev58+g96f5e34 is installed
#   warnings.warn(fmt_msg)
#
# 2019-07-19 14:26:59,118 - stpipe.Image2Pipeline.assign_wcs - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0028.asdf', 'filteroffset': '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_filteroffset_0004.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2019-07-19 14:26:59,198 - stpipe.Image2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  0.019264526 -0.014655577 0.021732133 0.016531592 359.990673023 0.019104246 359.987865956 -0.012096623
# 2019-07-19 14:26:59,199 - stpipe.Image2Pipeline.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  0.019264526 -0.014655577 0.021732133 0.016531592 359.990673023 0.019104246 359.987865956 -0.012096623
# 2019-07-19 14:26:59,199 - stpipe.Image2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2019-07-19 14:26:59,207 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2019-07-19 14:26:59,263 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field running with args (<ImageModel(1024, 1032) from det_image_seq3_MIRIMAGE_F1130Wexp1_rate.fits>,).
# 2019-07-19 14:26:59,350 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-07-19 14:26:59,351 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-07-19 14:26:59,352 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-07-19 14:26:59,359 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-07-19 14:26:59,457 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field done
# 2019-07-19 14:26:59,509 - stpipe.Image2Pipeline.photom - INFO - Step photom running with args (<ImageModel(1024, 1032) from det_image_seq3_MIRIMAGE_F1130Wexp1_rate.fits>,).
# 2019-07-19 14:26:59,529 - stpipe.Image2Pipeline.photom - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0042.fits
# 2019-07-19 14:26:59,534 - stpipe.Image2Pipeline.photom - INFO - Using area reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_area_0004.fits
# 2019-07-19 14:26:59,591 - stpipe.Image2Pipeline.photom - INFO - Using instrument: MIRI
# 2019-07-19 14:26:59,592 - stpipe.Image2Pipeline.photom - INFO -  detector: MIRIMAGE
# 2019-07-19 14:26:59,592 - stpipe.Image2Pipeline.photom - INFO -  exp_type: MIR_IMAGE
# 2019-07-19 14:26:59,593 - stpipe.Image2Pipeline.photom - INFO -  filter: F1130W
# 2019-07-19 14:26:59,622 - stpipe.Image2Pipeline.photom - INFO -  subarray: FULL
# 2019-07-19 14:26:59,623 - stpipe.Image2Pipeline.photom - INFO - PHOTMJSR value: 2.44947
# 2019-07-19 14:26:59,648 - stpipe.Image2Pipeline.photom - INFO - Pixel area map copied to output.
# 2019-07-19 14:26:59,653 - stpipe.Image2Pipeline.photom - INFO - Step photom done
# 2019-07-19 14:26:59,706 - stpipe.Image2Pipeline.resample - INFO - Step resample running with args (<ImageModel(1024, 1032) from det_image_seq3_MIRIMAGE_F1130Wexp1_rate.fits>,).
# 2019-07-19 14:26:59,729 - stpipe.Image2Pipeline.resample - INFO - Drizpars reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2019-07-19 14:27:00,374 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1095, 1099)
# 2019-07-19 14:27:00,900 - stpipe.Image2Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  0.021830928 -0.014675067 0.021830929 0.019077948 359.987954614 0.019077948 359.987954614 -0.014675067
# 2019-07-19 14:27:00,902 - stpipe.Image2Pipeline.resample - INFO - Step resample done
# 2019-07-19 14:27:00,903 - stpipe.Image2Pipeline - INFO - Finished processing product my_galaxy_dither3
# 2019-07-19 14:27:00,904 - stpipe.Image2Pipeline - INFO - Processing product my_galaxy_dither4
# 2019-07-19 14:27:00,905 - stpipe.Image2Pipeline - INFO - Working on input IMA_science/det_image_seq4_MIRIMAGE_F1130Wexp1_rate.fits ...
# 2019-07-19 14:27:01,093 - stpipe.Image2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<ImageModel(1024, 1032) from det_image_seq4_MIRIMAGE_F1130Wexp1_rate.fits>, ['IMA_background/det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits']).
# 2019-07-19 14:27:01,481 - stpipe.Image2Pipeline.bkg_subtract - INFO - Step bkg_subtract done
# 2019-07-19 14:27:01,531 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<ImageModel(1024, 1032) from det_image_seq4_MIRIMAGE_F1130Wexp1_rate.fits>,).
# 2019-07-19 14:27:01,815 - stpipe.Image2Pipeline.assign_wcs - WARNING - /anaconda3/envs/jwst7.3/lib/python3.6/site-packages/asdf/asdf.py:202: UserWarning: File 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0028.asdf' was created with extension 'asdf.extension.BuiltinExtension' from package asdf-2.4.0.dev1705, but older version asdf-2.4.0.dev58+g96f5e34 is installed
#   warnings.warn(fmt_msg)
#
# 2019-07-19 14:27:01,826 - stpipe.Image2Pipeline.assign_wcs - WARNING - /anaconda3/envs/jwst7.3/lib/python3.6/site-packages/asdf/asdf.py:202: UserWarning: File 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_filteroffset_0004.asdf' was created with extension 'asdf.extension.BuiltinExtension' from package asdf-2.4.0.dev1705, but older version asdf-2.4.0.dev58+g96f5e34 is installed
#   warnings.warn(fmt_msg)
#
# 2019-07-19 14:27:01,846 - stpipe.Image2Pipeline.assign_wcs - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0028.asdf', 'filteroffset': '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_filteroffset_0004.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2019-07-19 14:27:01,923 - stpipe.Image2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  0.017728644 -0.015154425 0.020196251 0.016032744 359.989137141 0.018605398 359.986330074 -0.012595471
# 2019-07-19 14:27:01,924 - stpipe.Image2Pipeline.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  0.017728644 -0.015154425 0.020196251 0.016032744 359.989137141 0.018605398 359.986330074 -0.012595471
# 2019-07-19 14:27:01,924 - stpipe.Image2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2019-07-19 14:27:01,933 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2019-07-19 14:27:01,986 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field running with args (<ImageModel(1024, 1032) from det_image_seq4_MIRIMAGE_F1130Wexp1_rate.fits>,).
# 2019-07-19 14:27:02,073 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-07-19 14:27:02,074 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-07-19 14:27:02,075 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-07-19 14:27:02,082 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2019-07-19 14:27:02,182 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field done
# 2019-07-19 14:27:02,232 - stpipe.Image2Pipeline.photom - INFO - Step photom running with args (<ImageModel(1024, 1032) from det_image_seq4_MIRIMAGE_F1130Wexp1_rate.fits>,).
# 2019-07-19 14:27:02,250 - stpipe.Image2Pipeline.photom - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0042.fits
# 2019-07-19 14:27:02,255 - stpipe.Image2Pipeline.photom - INFO - Using area reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_area_0004.fits
# 2019-07-19 14:27:02,315 - stpipe.Image2Pipeline.photom - INFO - Using instrument: MIRI
# 2019-07-19 14:27:02,315 - stpipe.Image2Pipeline.photom - INFO -  detector: MIRIMAGE
# 2019-07-19 14:27:02,316 - stpipe.Image2Pipeline.photom - INFO -  exp_type: MIR_IMAGE
# 2019-07-19 14:27:02,317 - stpipe.Image2Pipeline.photom - INFO -  filter: F1130W
# 2019-07-19 14:27:02,345 - stpipe.Image2Pipeline.photom - INFO -  subarray: FULL
# 2019-07-19 14:27:02,347 - stpipe.Image2Pipeline.photom - INFO - PHOTMJSR value: 2.44947
# 2019-07-19 14:27:02,373 - stpipe.Image2Pipeline.photom - INFO - Pixel area map copied to output.
# 2019-07-19 14:27:02,377 - stpipe.Image2Pipeline.photom - INFO - Step photom done
# 2019-07-19 14:27:02,436 - stpipe.Image2Pipeline.resample - INFO - Step resample running with args (<ImageModel(1024, 1032) from det_image_seq4_MIRIMAGE_F1130Wexp1_rate.fits>,).
# 2019-07-19 14:27:02,459 - stpipe.Image2Pipeline.resample - INFO - Drizpars reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2019-07-19 14:27:03,092 - stpipe.Image2Pipeline.resample - INFO - Drizzling (1024, 1032) --> (1095, 1099)
# 2019-07-19 14:27:03,612 - stpipe.Image2Pipeline.resample - INFO - Update S_REGION to POLYGON ICRS  0.020295046 -0.015173915 0.020295047 0.018579100 359.986418732 0.018579100 359.986418732 -0.015173915
# 2019-07-19 14:27:03,615 - stpipe.Image2Pipeline.resample - INFO - Step resample done
# 2019-07-19 14:27:03,615 - stpipe.Image2Pipeline - INFO - Finished processing product my_galaxy_dither4
# 2019-07-19 14:27:03,616 - stpipe.Image2Pipeline - INFO - ... ending calwebb_image2
# 2019-07-19 14:27:03,945 - stpipe.Image2Pipeline - INFO - Saved model in demo_output/my_galaxy_dither1_cal.fits
# 2019-07-19 14:27:04,299 - stpipe.Image2Pipeline - INFO - Saved model in demo_output/my_galaxy_dither2_cal.fits
# 2019-07-19 14:27:04,623 - stpipe.Image2Pipeline - INFO - Saved model in demo_output/my_galaxy_dither3_cal.fits
# 2019-07-19 14:27:04,980 - stpipe.Image2Pipeline - INFO - Saved model in demo_output/my_galaxy_dither4_cal.fits
# 2019-07-19 14:27:04,981 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline done

# %% [markdown]
# We can plot the before (rate) and after (cal) images for the first dither position

# %%
# open the input image as a jwst data model
with datamodels.open(my_science_files[0]) as in_dm:

    fig, axs = plt.subplots(1, 2, figsize=(14, 7), sharey=True)

    axs[0].imshow(in_dm.data, cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=10, vmax=1000))
    axs[0].annotate('DMS Level 2A (rate)', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
    axs[0].set_facecolor('black')
    axs[1].imshow(dm_cont[0].data, cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=10, vmax=1000))
    axs[1].annotate('DMS Level 2B (cal)', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
    axs[1].set_facecolor('black')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Command line
#
# To achieve the same result from the command line there are a couple of options. However, one must still generate the association file. In this case, it is best to copy the template above into a text file and save it to `my_galaxy_lvl2_asn.json` or whatever you choose. The content is printed here for convenience.

# %%
{
    "asn_type": "image2",
    "asn_rule": "DMSLevel2bBase",
    "version_id": null,
    "code_version": "0.13.7",
    "degraded_status": "No known degraded exposures in association.",
    "program": "noprogram",
    "products": [
        {
            "name": "my_galaxy_dither1",
            "members": [
                {
                    "expname": "IMA_science/det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits",
                    "exptype": "science"
                },
                {
                    "expname": "IMA_background/det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits",
                    "exptype": "background"
                }
            ]
        },
        {
            "name": "my_galaxy_dither2",
            "members": [
                {
                    "expname": "IMA_science/det_image_seq2_MIRIMAGE_F1130Wexp1_rate.fits",
                    "exptype": "science"
                },
                {
                    "expname": "IMA_background/det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits",
                    "exptype": "background"
                }
            ]
        },
        {
            "name": "my_galaxy_dither3",
            "members": [
                {
                    "expname": "IMA_science/det_image_seq3_MIRIMAGE_F1130Wexp1_rate.fits",
                    "exptype": "science"
                },
                {
                    "expname": "IMA_background/det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits",
                    "exptype": "background"
                }
            ]
        },
        {
            "name": "my_galaxy_dither4",
            "members": [
                {
                    "expname": "IMA_science/det_image_seq4_MIRIMAGE_F1130Wexp1_rate.fits",
                    "exptype": "science"
                },
                {
                    "expname": "IMA_background/det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits",
                    "exptype": "background"
                }
            ]
        }
    ],
    "asn_pool": "my_galaxy_pool"
}

# %% [markdown]
# **Option 1:**
# Run the `Image2Pipeline` class using the `strun` command:
#
# ```bash
# mkdir demo_output
#
# strun jwst.pipeline.Image2Pipeline det_image_seq1_MIRIMAGE_F1130Wexp1.fits --output_dir demo_output
# ```
#
# This will produce the same output file in the user-defined `--output_dir`
#
#
# **Option 2:**
# Collect the pipeline configuration files in your working directory using `collect_pipeline_configs` and then run the `Detector1Pipeline` using the `strun` command with the associated `calwebb_detector1.cfg` file. This option is a little more flexible as one can create edit the cfg files, use them again, etc.
#
# ```bash
# mkdir demo_output
#
# collect_pipeline_cfgs cfgs/
#
# strun cfgs/calwebb_detector1.cfg det_image_seq1_MIRIMAGE_F1130Wexp1.fits --output_dir demo_output
# ```
#
# This will produce the same output file in the user-defined `--output_dir`

# %% [markdown]
# ## Further examples
#
# Other notebooks with more complex examples can be found here:
#
# *To be added*
