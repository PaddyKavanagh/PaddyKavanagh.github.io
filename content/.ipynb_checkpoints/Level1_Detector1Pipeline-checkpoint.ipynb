# %% [markdown]
# ## Ramps-to-slopes:  Detector1Pipeline   (MIRI CALDETECTOR1)
#
# The `Detector1Pipeline` takes DMS Level 1B data and applies basic detector-level corrections to all exposure types. It is applied to one exposure at a time. It is sometimes referred to as “ramps-to-slopes” processing, because the input raw data are in the form of one or more ramps (integrations) containing accumulating counts from the non-destructive detector readouts and the output is a corrected countrate (slope) image.
#
# Official documentation for `Detector1Pipeline` can be found here:
#
# <https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_detector1.html>
#
# The `Detector1Pipeline` comprises a linear series of steps to first calibrate the pixel ramps, detect cosmic ray jumps, and fit a linear function to the calibrate ramps to produce a slope or DMS Level 2A image. The steps applied to MIRI data in order are:
#
# |Step|Description|
# |:---|:---|
# |`dq_init`|populates the DQ mask for the input dataset|
# |`saturation`|flags saturated pixel values|
# |`firstframe`|flags the first group in every integration as bad|
# |`lastframe`|flags the last group in every integration as bad|
# |`linearity`|corrects for detector non-linearity|
# |`rscd`|correct for the reset switch charge decay|
# |`dark_current`|subtracts dark current data|
# |`refpix`|corrects for pixel drifts using the reference pixels|
# |`jump`|detects jumps in the ramps by looking for outliers in each integration|
# |`ramp_fit`|determines count rate for each pixel by performing a linear fit to ramps|
#
# For more information and examples of each of the steps click on the links in the side bar.

# %% [markdown]
# ### Input data
#
# An example of running the file through the Detector1Pipeline is now shown using a simple simulated observation of a galaxy and some point sources with the MIRI Imager (F1130W filter) produced with [MIRISim v2.1](http://miri.ster.kuleuven.be/bin/view/Public/MIRISimPublicRelease2dot1).

# %% [markdown]
# ### Python
#
# Start by importing what will be used and set the `CRDS_CONTEXT`

# %%
# imports
import os, glob, shutil
import numpy as np
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
from subprocess import call
from jwst import datamodels

# set the CRDS_CONTEXT
os.environ["CRDS_CONTEXT"] = "jwst_0535.pmap"

# %% [markdown]
# Import Detector1Pipeline and print the docstring to show some information

# %%
from jwst.pipeline import Detector1Pipeline
print(Detector1Pipeline.__doc__)
# Out:
#     Detector1Pipeline: Apply all calibration steps to raw JWST
#     ramps to produce a 2-D slope product. Included steps are:
#     group_scale, dq_init, saturation, ipc, superbias, refpix, rscd,
#     lastframe, linearity, dark_current, persistence, jump detection,
#     ramp_fit, and gain_scale.

# %% [markdown]
# Set the name of the input file, where the output should be saved and run the pipeline. The output level 2A files will be saved in `my_output_dir` as `_rate.fits`. Note that we must explicitly skip the IPC step when running from Python. This is achieved by passing the `skip` parameter to the step in a Python `dict`.
#
# *Parameters used:*
#
# `output_use_model` : boolean, optional, default=False
# &nbsp;&nbsp;&nbsp;&nbsp; propagate the input filename to the output
#
# `save_results`: boolean, optional, default=False
# &nbsp;&nbsp;&nbsp;&nbsp; save the results to file
#
# `output_dir` : boolean, optional, default is the working directory
# &nbsp;&nbsp;&nbsp;&nbsp; the location to save the output
#
# `steps` : dict, optional
# &nbsp;&nbsp;&nbsp;&nbsp; dict of user-defined parameters for individual steps
#
# Note that the `Detector1Pipeline` will return the rate datamodel so we set this to the `dm` variable.

# %%
# user specified
my_input_file = 'det_image_seq1_MIRIMAGE_F1130Wexp1.fits'
my_output_dir = 'demo_output'

# the output directory should be created if it doesn't exist
if not os.path.exists(my_output_dir): 
    os.mkdir(my_output_dir)

# run the pipeline
dm = Detector1Pipeline.call(my_input_file, output_use_model=True, save_results=True, 
                            output_dir=my_output_dir, steps={'ipc': {'skip': True}})
# Out:
# 2019-07-22 15:25:57,504 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2019-07-22 15:25:57,505 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2019-07-22 15:25:57,508 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2019-07-22 15:25:57,509 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2019-07-22 15:25:57,511 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2019-07-22 15:25:57,513 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2019-07-22 15:25:57,515 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2019-07-22 15:25:57,517 - stpipe.Detector1Pipeline.rscd - INFO - RSCD_Step instance created.
# 2019-07-22 15:25:57,519 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2019-07-22 15:25:57,521 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2019-07-22 15:25:57,524 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2019-07-22 15:25:57,527 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2019-07-22 15:25:57,529 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2019-07-22 15:25:57,530 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2019-07-22 15:25:57,532 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2019-07-22 15:25:57,534 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2019-07-22 15:25:57,584 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('det_image_seq1_MIRIMAGE_F1130Wexp1.fits',).
# 2019-07-22 15:25:58,043 - stpipe.Detector1Pipeline - WARNING - /anaconda3/envs/jwst7.3/lib/python3.6/site-packages/jwst-0.13.7-py3.6.egg/jwst/datamodels/util.py:165: NoTypeWarning: model_type not found. Opening det_image_seq1_MIRIMAGE_F1130Wexp1.fits as a RampModel
#   warnings.warn(errmsg, NoTypeWarning)
#
# 2019-07-22 15:25:58,045 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'det_image_seq1_MIRIMAGE_F1130Wexp1.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'refpix', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2019-07-22 15:26:00,601 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0058.fits'.
# 2019-07-22 15:26:00,602 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits'.
# 2019-07-22 15:26:00,603 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0024.fits'.
# 2019-07-22 15:26:00,603 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0023.fits'.
# 2019-07-22 15:26:00,604 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2019-07-22 15:26:00,605 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0057.fits'.
# 2019-07-22 15:26:00,606 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2019-07-22 15:26:00,606 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0009.fits'.
# 2019-07-22 15:26:00,607 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0022.fits'.
# 2019-07-22 15:26:00,608 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2019-07-22 15:26:00,608 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2019-07-22 15:26:00,609 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2019-07-22 15:26:00,610 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2019-07-22 15:26:00,855 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(2, 20, 1024, 1032) from det_image_seq1_MIRIMAGE_F1130Wexp1.fits>,).
# 2019-07-22 15:26:00,866 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES={} is a power of 2; correction not needed
# 2019-07-22 15:26:00,867 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2019-07-22 15:26:00,868 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2019-07-22 15:26:00,919 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(2, 20, 1024, 1032) from det_image_seq1_MIRIMAGE_F1130Wexp1.fits>,).
# 2019-07-22 15:26:00,932 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0023.fits
# 2019-07-22 15:26:01,989 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2019-07-22 15:26:02,067 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(2, 20, 1024, 1032) from det_image_seq1_MIRIMAGE_F1130Wexp1.fits>,).
# 2019-07-22 15:26:02,082 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0022.fits
# 2019-07-22 15:26:02,640 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2019-07-22 15:26:02,690 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(2, 20, 1024, 1032) from det_image_seq1_MIRIMAGE_F1130Wexp1.fits>,).
# 2019-07-22 15:26:02,691 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2019-07-22 15:26:02,692 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2019-07-22 15:26:02,737 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<RampModel(2, 20, 1024, 1032) from det_image_seq1_MIRIMAGE_F1130Wexp1.fits>,).
# 2019-07-22 15:26:02,917 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2019-07-22 15:26:02,963 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<RampModel(2, 20, 1024, 1032) from det_image_seq1_MIRIMAGE_F1130Wexp1.fits>,).
# 2019-07-22 15:26:03,142 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2019-07-22 15:26:03,193 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(2, 20, 1024, 1032) from det_image_seq1_MIRIMAGE_F1130Wexp1.fits>,).
# 2019-07-22 15:26:03,209 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0024.fits
# 2019-07-22 15:26:03,968 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2019-07-22 15:26:04,020 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(2, 20, 1024, 1032) from det_image_seq1_MIRIMAGE_F1130Wexp1.fits>,).
# 2019-07-22 15:26:04,032 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0009.fits
# 2019-07-22 15:26:04,209 - stpipe.Detector1Pipeline.rscd - INFO -  Working on integration 2
# 2019-07-22 15:26:05,343 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2019-07-22 15:26:05,394 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(2, 20, 1024, 1032) from det_image_seq1_MIRIMAGE_F1130Wexp1.fits>,).
# 2019-07-22 15:26:05,408 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0058.fits
# 2019-07-22 15:26:05,502 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=2, ngroups=20, nframes=1, groupgap=0
# 2019-07-22 15:26:05,503 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=200, nframes=1, groupgap=0
# 2019-07-22 15:26:13,722 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2019-07-22 15:26:13,806 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(2, 20, 1024, 1032) from det_image_seq1_MIRIMAGE_F1130Wexp1.fits>,).
# 2019-07-22 15:26:13,818 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = True
# 2019-07-22 15:26:13,818 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = True
# 2019-07-22 15:26:13,819 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = 11
# 2019-07-22 15:26:13,819 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = 1.000000
# 2019-07-22 15:26:13,820 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# 2019-07-22 15:26:13,967 - stpipe.Detector1Pipeline.refpix - INFO - Subtracting initial read from each integration
# 2019-07-22 15:26:14,594 - stpipe.Detector1Pipeline.refpix - INFO - Adding initial read back in
# 2019-07-22 15:26:14,679 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2019-07-22 15:26:14,735 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(2, 20, 1024, 1032) from det_image_seq1_MIRIMAGE_F1130Wexp1.fits>,).
# 2019-07-22 15:26:14,782 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2019-07-22 15:26:14,787 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits
# 2019-07-22 15:26:14,817 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0057.fits
# 2019-07-22 15:26:15,129 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2019-07-22 15:26:15,719 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 1
# 2019-07-22 15:26:16,853 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier Two point found 240878 pixels with at least one CR
# 2019-07-22 15:26:24,987 - stpipe.Detector1Pipeline.jump - INFO -  working on integration 2
# 2019-07-22 15:26:26,097 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier Two point found 236404 pixels with at least one CR
# 2019-07-22 15:26:34,201 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 19.418573
# 2019-07-22 15:26:34,204 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2019-07-22 15:26:34,261 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(2, 20, 1024, 1032) from det_image_seq1_MIRIMAGE_F1130Wexp1.fits>,).
# 2019-07-22 15:26:34,278 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0057.fits
# 2019-07-22 15:26:34,347 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits
# 2019-07-22 15:26:34,364 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2019-07-22 15:26:34,365 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2019-07-22 15:26:34,378 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 1
# 2019-07-22 15:26:34,381 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2019-07-22 15:26:34,382 - stpipe.Detector1Pipeline.ramp_fit - INFO - Effective integration time per group: 2.77504
# 2019-07-22 15:28:09,788 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 20
# 2019-07-22 15:28:09,789 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# 2019-07-22 15:28:09,853 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2019-07-22 15:28:09,956 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(1024, 1032) from det_image_seq1_MIRIMAGE_F1130Wexp1.fits>,).
# 2019-07-22 15:28:09,998 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2019-07-22 15:28:09,998 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2019-07-22 15:28:10,002 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2019-07-22 15:28:10,050 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(2, 1024, 1032) from det_image_seq1_MIRIMAGE_F1130Wexp1.fits>,).
# 2019-07-22 15:28:10,126 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2019-07-22 15:28:10,126 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2019-07-22 15:28:10,130 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2019-07-22 15:28:10,379 - stpipe.Detector1Pipeline - INFO - Saved model in demo_output/det_image_seq1_MIRIMAGE_F1130Wexp1_rateints.fits
# 2019-07-22 15:28:10,380 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2019-07-22 15:28:10,511 - stpipe.Detector1Pipeline - INFO - Saved model in demo_output/det_image_seq1_MIRIMAGE_F1130Wexp1_rate.fits
# 2019-07-22 15:28:10,512 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done

# %% [markdown]
# We can plot the before (last frame of first integration) and after images

# %%
# open the input image as a jwst data model
with datamodels.open(my_input_file) as in_dm:

    fig, axs = plt.subplots(1, 2, figsize=(14, 7), sharey=True)

    axs[0].imshow(in_dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1e4,vmax=2e4))
    axs[0].annotate('DMS Level 1B (ramp)', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
    axs[0].set_facecolor('black')
    axs[1].imshow(dm.data, cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=5, vmax=400))
    axs[1].annotate('DMS Level 2A (slope)', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
    axs[1].set_facecolor('black')
    plt.tight_layout()
    plt.show()
# Out:
# 2019-07-22 15:29:35,390 - stpipe - WARNING - /anaconda3/envs/jwst7.3/lib/python3.6/site-packages/jwst-0.13.7-py3.6.egg/jwst/datamodels/util.py:165: NoTypeWarning: model_type not found. Opening det_image_seq1_MIRIMAGE_F1130Wexp1.fits as a RampModel
#   warnings.warn(errmsg, NoTypeWarning)

# %% [markdown]
# ### Command line
#
# To achieve the same result from the command line there are a couple of options.
#
# **Option 1:**
# Run the `Detector1Pipeline` class using the `strun` command:
#
# ```bash
# mkdir demo_output
#
# strun jwst.pipeline.Detector1Pipeline det_image_seq1_MIRIMAGE_F1130Wexp1.fits --output_dir demo_output
# ```
#
# This will produce the same output file in the user-defined `--output_dir`
#
#
# **Option 2:**
# Collect the pipeline configuration files in your working directory using `collect_pipeline_configs` and then run the `Detector1Pipeline` using the `strun` command with the associated `calwebb_detector1.cfg` file. This option is a little more flexible as one can create edit the cfg files, use them again, etc.
#
# ```bash
# mkdir demo_output
#
# collect_pipeline_cfgs cfgs/
#
# strun cfgs/calwebb_detector1.cfg det_image_seq1_MIRIMAGE_F1130Wexp1.fits --output_dir demo_output
# ```
#
# This will produce the same output file in the user-defined `--output_dir`

# %% [markdown]
# ## Further examples
#
# Other notebooks with more complex examples can be found here:
#
# *To be added*
